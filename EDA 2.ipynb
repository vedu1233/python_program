# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib  inline 
plt.rcParams["figure.figsize"] =(10,5)
plt.rcParams["figure.dpi"] =300
import warnings
warnings.filterwarnings("ignore")

# %%
df =pd.read_csv("data_clean1.csv")

# %%
df.head(4)
# Out:
#    Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0   41.0    190.0   7.4     5    1  2010    67       S
# 1   36.0    118.0   8.0     5    2  2010    72       C
# 2   12.0    149.0  12.6     5    3  2010    74      PS
# 3   18.0    313.0  11.5     5    4  2010    62       S

# %%
df['Month'].unique()
# Out:
# array(['5', 'May', '6', '7', '8', '9'], dtype=object)

# %%
df["Month"].value_counts()
# Out:
# Month
# 9      34
# 5      31
# 7      31
# 8      31
# 6      30
# May     1
# Name: count, dtype: int64

# %%
df["Month"].replace('May',5,inplace =True
                   )

# %%
df['Month'].unique()
# Out:
# array(['5', 5, '6', '7', '8', '9'], dtype=object)

# %%
df.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
df["Month"]=df['Month'].astype(int)

# %%
df.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month        int32
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 153    False
# 154    False
# 155    False
# 156     True
# 157    False
# Length: 158, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df[df.duplicated()] # this will extract the duplicated record
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3      9   28  2010    75       S

# %% [markdown]
# keep : {'first', 'last', False}, default 'first'
#     Determines which duplicates (if any) to mark.
#
#     - ``first`` : Mark duplicates as ``True`` except for the first occurrence.
#     - ``last`` : Mark duplicates as ``True`` except for the last occurrence.
#     - False : Mark all duplicates as ``True``.

# %%
df[df.duplicated(keep=False)] # shows the duplicate record
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3      9   28  2010    75       S
# 156   14.0    191.0  14.3      9   28  2010    75       S

# %%
df[df.duplicated(keep='first')] # shows the duplicate record
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3      9   28  2010    75       S

# %%
df[df.duplicated(keep='last')] # shows the duplicate record
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3      9   28  2010    75       S

# %%
df.drop_duplicates(inplace =True) # this will drop all duplicates except origional value # inplace means keep changes perment in origional dataset

# %%
df.shape
# Out:
# (157, 8)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Drop column

# %%
df.head()
# Out:
#    Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0   41.0    190.0   7.4      5    1  2010    67       S
# 1   36.0    118.0   8.0      5    2  2010    72       C
# 2   12.0    149.0  12.6      5    3  2010    74      PS
# 3   18.0    313.0  11.5      5    4  2010    62       S
# 4    NaN      NaN  14.3      5    5  2010    56       S

# %%
df.tail(10)
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 147   14.0     20.0  16.6      9   25  2010    63      PS
# 148   30.0    193.0   6.9      9   26  2010    70       C
# 149    NaN    145.0  13.2      9   27  2010    77      PS
# 150   14.0    191.0  14.3      9   28  2010    75       S
# 151   18.0    131.0   8.0      9   29  2010    76      PS
# 152   20.0    223.0  11.5      9   30  2010    68       S
# 153   41.0    190.0   7.4      5    1  2010    67       C
# 154   30.0    193.0   6.9      9   26  2010    70      PS
# 155    NaN    145.0  13.2      9   27  2010    77       S
# 157   18.0    131.0   8.0      9   29  2010    76       C

# %%
df["Year"].value_counts()
# Out:
# Year
# 2010    157
# Name: count, dtype: int64

# %%
df.drop(columns =['Year'],inplace =True)

# %%
df.head()
# Out:
#    Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 0   41.0    190.0   7.4      5    1    67       S
# 1   36.0    118.0   8.0      5    2    72       C
# 2   12.0    149.0  12.6      5    3    74      PS
# 3   18.0    313.0  11.5      5    4    62       S
# 4    NaN      NaN  14.3      5    5    56       S

# %%
df.drop(columns =['Ozone','Month'])
# Out:
#      Solar.R  Wind  Day  Temp Weather
# 0      190.0   7.4    1    67       S
# 1      118.0   8.0    2    72       C
# 2      149.0  12.6    3    74      PS
# 3      313.0  11.5    4    62       S
# 4        NaN  14.3    5    56       S
# ..       ...   ...  ...   ...     ...
# 152    223.0  11.5   30    68       S
# 153    190.0   7.4    1    67       C
# 154    193.0   6.9   26    70      PS
# 155    145.0  13.2   27    77       S
# 157    131.0   8.0   29    76       C
#
# [157 rows x 5 columns]

# %%
df.drop(index=[1]) # delete a record temporary
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 0     41.0    190.0   7.4      5    1    67       S
# 2     12.0    149.0  12.6      5    3    74      PS
# 3     18.0    313.0  11.5      5    4    62       S
# 4      NaN      NaN  14.3      5    5    56       S
# 5     28.0      NaN  14.9      5    6    66       C
# ..     ...      ...   ...    ...  ...   ...     ...
# 152   20.0    223.0  11.5      9   30    68       S
# 153   41.0    190.0   7.4      5    1    67       C
# 154   30.0    193.0   6.9      9   26    70      PS
# 155    NaN    145.0  13.2      9   27    77       S
# 157   18.0    131.0   8.0      9   29    76       C
#
# [156 rows x 7 columns]

# %%
df.drop(index =[1,4,5]) # this will drop the rows or records with given index
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 0     41.0    190.0   7.4      5    1    67       S
# 2     12.0    149.0  12.6      5    3    74      PS
# 3     18.0    313.0  11.5      5    4    62       S
# 6     23.0    299.0   8.6      5    7    65      PS
# 7     19.0     99.0  13.8      5    8    59       C
# ..     ...      ...   ...    ...  ...   ...     ...
# 152   20.0    223.0  11.5      9   30    68       S
# 153   41.0    190.0   7.4      5    1    67       C
# 154   30.0    193.0   6.9      9   26    70      PS
# 155    NaN    145.0  13.2      9   27    77       S
# 157   18.0    131.0   8.0      9   29    76       C
#
# [154 rows x 7 columns]

# %% [markdown]
# # Rename the column

# %%
df.head()
# Out:
#    Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 0   41.0    190.0   7.4      5    1    67       S
# 1   36.0    118.0   8.0      5    2    72       C
# 2   12.0    149.0  12.6      5    3    74      PS
# 3   18.0    313.0  11.5      5    4    62       S
# 4    NaN      NaN  14.3      5    5    56       S

# %%
df.rename(columns={'Solar.R':'solar','Temp':'Tempreture'},inplace =True) # rename the column we pas columns with dictionary

# %%
df.head()
# Out:
#    Ozone  solar  Wind  Month  Day  Tempreture Weather
# 0   41.0  190.0   7.4      5    1          67       S
# 1   36.0  118.0   8.0      5    2          72       C
# 2   12.0  149.0  12.6      5    3          74      PS
# 3   18.0  313.0  11.5      5    4          62       S
# 4    NaN    NaN  14.3      5    5          56       S

# %% [markdown]
# # missing values imputation

# %% [raw]
# reasons of missing values:
# 1) data emtry error
# 2)issues with machine
# 3)improper data handeling etc
#
# ##  missing  values treatment
# 0 to 5% missing values = drop the rows
# 6 to 45 % missing values =replace the missing values
# 50 % missing values = drop the column

# %%
df.isna().count()
# Out:
# Ozone         157
# solar         157
# Wind          157
# Month         157
# Day           157
# Tempreture    157
# Weather       157
# dtype: int64

# %%
df.isna().sum()
# Out:
# Ozone         38
# solar          7
# Wind           0
# Month          0
# Day            0
# Tempreture     0
# Weather        3
# dtype: int64

# %%
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %%
len(df)
# Out:
# 157

# %%
for i in df.isna().sum():
    print((i/len(df))*100)
# Out:
# 24.203821656050955
# 4.45859872611465
# 0.0
# 0.0
# 0.0
# 0.0
# 1.910828025477707

# %%
df.hist()
plt.tight_layout()

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
plt.boxplot(x =df['Wind'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f6b11c5c10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f6b11c61e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f6b114bb00>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f6b11c6780>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f6b11c6a20>],
#  'means': []}

# %%
ozone_median =df['Ozone'].median()

# %%
ozone_median
# Out:
# 31.0

# %%
df['Ozone'].fillna(ozone_median,inplace =True)

# %%
df.isna().sum()
# Out:
# Ozone         0
# solar         7
# Wind          0
# Month         0
# Day           0
# Tempreture    0
# Weather       3
# dtype: int64

# %%
# replace the solar column null values with mean

# %%
solar_mean =df["solar"].mean()

# %%
solar_mean
# Out:
# 185.36666666666667

# %%
df['solar'].fillna(solar_mean,inplace = True)

# %%
df['solar'].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Ozone         0
# solar         0
# Wind          0
# Month         0
# Day           0
# Tempreture    0
# Weather       3
# dtype: int64

# %%
df['Weather'].value_counts()
# Out:
# Weather
# S     58
# C     49
# PS    47
# Name: count, dtype: int64

# %%
df['Weather'].value_counts()
# Out:
# Weather
# S     58
# C     49
# PS    47
# Name: count, dtype: int64

# %%
df['Weather'].mode()
# Out:
# 0    S
# Name: Weather, dtype: object

# %%
w_mode =df['Weather'].mode()[0]

# %%
df['Weather'].fillna(w_mode,inplace =True)

# %%
df.isna().sum()
# Out:
# Ozone         0
# solar         0
# Wind          0
# Month         0
# Day           0
# Tempreture    0
# Weather       0
# dtype: int64

# %% [raw]
#  # outlier detection
#  1.histogram
#  2.boxplot
#  3.bar plot

# %% [raw]
# capping = replacing the outlier values is called as capping
# in capping all outliers values are replaced by upper extreme

# %% [markdown]
# # user define function

# %%
def userfunction():
    print('user function')
    print('hello')

# %%
userfunction()
# Out:
# user function
# hello

# %%
def add1(num1,num2):
    print(num1+num2)

# %%
add1(12,14)
# Out:
# 26

# %%
def arithmatic(num1,num2):
    print('addition  :',num1+num2)
    print('substraction  :',num1-num2)
    print('multiply  :',num1*num2)
    print('division  :',num1/num2)

# %%
arithmatic(12,3)
# Out:
# addition  : 15
# substraction  : 9
# multiply  : 36
# division  : 4.0

# %%
def addtext(text1,text2):
    print(text1+ "   "+text2)

# %%
addtext("vedant","pawar")
# Out:
# vedant   pawar

# %%
df['Ozone'].quantile(0.25)
# Out:
# 21.0

# %%
df['Ozone'].quantile(0.75)
# Out:
# 45.0

# %%
def outlier_detection(data,colname):
    q1 =data[colname].quantile(0.25)
    q2 =data[colname].quantile(0.75)
    iqr =q2-q1
    upper_extreme =q2+(1.5*iqr)
    lower_extreme =q1-(1.5*iqr)
    return lower_extreme,upper_extreme,q1,q2

# %%
outlier_detection(df,'Ozone')
# Out:
# (-15.0, 81.0, 21.0, 45.0)

# %%
df.head(1)
# Out:
#    Ozone  solar  Wind  Month  Day  Tempreture Weather
# 0   41.0  190.0   7.4      5    1          67       S

# %%
outlier_detection(df,'Wind')
# Out:
# (1.2500000000000009, 17.65, 7.4, 11.5)

# %%
import plotly.express as pe

# %%
pe.scatter(x =df['Ozone'],y =df['Temp'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Temp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[289], line 1
# ----> 1 pe.scatter(x =df['Ozone'],y =df['Temp'])
#
# ...

# %%
 s =(df['Ozone']>81).value_counts()

# %%
s

# %%
df[df['Ozone']>81].shape[0] # 0 is for rows and 1 for column

# %%
df.loc[df['Ozone']>81.0,'Ozone']

# %%
df.loc[df['Ozone']>81.0,'Ozone'] =81 # i assign 81 to the ozone column which has >81

# %%
df.loc[df['Ozone']>81.0,'Ozone']

# %%
df[df['Ozone']==81]

# %%
outlier_detection(df,'Wind')

# %%
sns.boxplot(df['Wind'])

# %%
df[df['Wind']>17.65]

# %%
df.loc[df['Wind']>17.65,'Wind'] == 17.65

# %%
df[df['Wind']>17.65]

# %%
df.loc[df['Wind']>17.65,'Wind'] = 17.65

# %%
df[df['Wind']>17.65]

# %%
df.boxplot()

# %%
df.boxplot() # after removing the

# %% [markdown]
# # scatter plot and correlation

# %%
df.shape

# %%
df.head(2)

# %%
sns.pairplot(df)

# %%
df['Weather'].value_counts()

# %%
df.corr(numeric_only=True )# check the correlation betweem numeric column

# %%
(df.corr(numeric_only =True)) # corr ranged from -1 to +1

# %%
sns.heatmap(df.corr(numeric_only =True),annot = True,cmap ='viridis') # annot display the value inside graph

# %%
sns.heatmap(df.corr(numeric_only =True),annot = True,cmap ='rainbow') # annot display the value inside graph

# %% [markdown]
# # transformation

# %%
df =pd.get_dummies(data =df,columns =['Weather'])

# %%
df # gives the dummy data of categorical column
# Out:
#      Ozone       solar  Wind  Month  Day  Tempreture  Weather_C  Weather_PS  \
# 0     41.0  190.000000   7.4      5    1          67      False       False
# 1     36.0  118.000000   8.0      5    2          72       True       False
# 2     12.0  149.000000  12.6      5    3          74      False        True
# 3     18.0  313.000000  11.5      5    4          62      False       False
# 4     31.0  185.366667  14.3      5    5          56      False       False
# ..     ...         ...   ...    ...  ...         ...        ...         ...
# 152   20.0  223.000000  11.5      9   30          68      False       False
# 153   41.0  190.000000   7.4      5    1          67       True       False
# 154   30.0  193.000000   6.9      9   26          70      False        True
# 155   31.0  145.000000  13.2      9   27          77      False       False
# 157   18.0  131.000000   8.0      9   29          76       True       False
#
#      Weather_S
# 0         True
# 1        False
# ...

# %% [markdown]
# # scaling the data

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
sc =StandardScaler()

# %%
pd.DataFrame(sc.fit_transform(df),columns = df.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12560\361867901.py in ?()
# ----> 1 pd.DataFrame(sc.fit_transform(df),columns = df.columns)
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     293     @wraps(f)
#     294     def wrapped(self, X, *args, **kwargs):
# --> 295         data_to_wrap = f(self, X, *args, **kwargs)
#     296         if isinstance(data_to_wrap, tuple):
#     297             # only wrap the first output for cross decomposition
#     298             return_tuple = (
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#    1094                 )
#    1095
#    1096         if y is None:
#    1097             # fit method of arity 1 (unsupervised transformation)
# -> 1098             return self.fit(X, **fit_params).transform(X)
#    1099         else:
# ...

# %%
scaled_data =pd.DataFrame(sc.fit_transform(df),columns = df.columns)

# %%
scaled_data
# Out:
#         Ozone     solar      Wind     Month       Day  Tempreture  Weather_C  \
# 0    0.062828  0.053428 -0.724079 -1.412198 -1.668937   -1.146116  -0.673575
# 1   -0.111448 -0.776816 -0.552356 -1.412198 -1.557152   -0.612802   1.484615
# 2   -0.947971 -0.419350  0.764184 -1.412198 -1.445367   -0.399476  -0.673575
# 3   -0.738840  1.471761  0.449359 -1.412198 -1.333583   -1.679431  -0.673575
# 4   -0.285723  0.000000  1.250731 -1.412198 -1.221798   -2.319408  -0.673575
# ..        ...       ...       ...       ...       ...         ...        ...
# 152 -0.669130  0.433956  0.449359  1.385469  1.572816   -1.039454  -0.673575
# 153  0.062828  0.053428 -0.724079 -1.412198 -1.668937   -1.146116   1.484615
# 154 -0.320578  0.088021 -0.867181  1.385469  1.125678   -0.826128  -0.673575
# 155 -0.285723 -0.465475  0.935906  1.385469  1.237462   -0.079488  -0.673575
# 156 -0.738840 -0.626911 -0.552356  1.385469  1.461032   -0.186150   1.484615
#
#      Weather_PS  Weather_S
# ...

# %%
scaled_data.describe() # mean of scaled data  is 0 and std =1
# Out:
#               Ozone         solar          Wind         Month           Day  \
# count  1.570000e+02  1.570000e+02  1.570000e+02  1.570000e+02  1.570000e+02
# mean  -5.657187e-17 -9.051500e-17 -4.525750e-17  1.810300e-16 -2.262875e-17
# std    1.003200e+00  1.003200e+00  1.003200e+00  1.003200e+00  1.003200e+00
# min   -1.331377e+00 -2.056776e+00 -2.355444e+00 -1.412198e+00 -1.668937e+00
# 25%   -6.342745e-01 -6.730358e-01 -7.240788e-01 -7.127815e-01 -8.864446e-01
# 50%   -2.857232e-01  8.802124e-02 -6.580877e-02 -1.336465e-02  7.832041e-03
# 75%    2.022485e-01  8.029536e-01  4.493591e-01  6.860522e-01  9.021087e-01
# max    4.489429e+00  1.713916e+00  3.082439e+00  1.385469e+00  1.684601e+00
#
#          Tempreture     Weather_C    Weather_PS     Weather_S
# count  1.570000e+02  1.570000e+02  1.570000e+02  1.570000e+02
# mean   2.036587e-16  4.242891e-17 -8.485781e-18 -7.849347e-17
# std    1.003200e+00  1.003200e+00  1.003200e+00  1.003200e+00
# ...

# %%
mn = MinMaxScaler()

# %%
minmax_scaled =pd.DataFrame(mn.fit_transform(df),columns =df.columns)

# %%
minmax_scaled
# Out:
#         Ozone     solar      Wind  Month       Day  Tempreture  Weather_C  \
# 0    0.239521  0.559633  0.300000    0.0  0.000000    0.268293        0.0
# 1    0.209581  0.339450  0.331579    0.0  0.033333    0.390244        1.0
# 2    0.065868  0.434251  0.573684    0.0  0.066667    0.439024        0.0
# 3    0.101796  0.935780  0.515789    0.0  0.100000    0.146341        0.0
# 4    0.179641  0.545464  0.663158    0.0  0.133333    0.000000        0.0
# ..        ...       ...       ...    ...       ...         ...        ...
# 152  0.113772  0.660550  0.515789    1.0  0.966667    0.292683        0.0
# 153  0.239521  0.559633  0.300000    0.0  0.000000    0.268293        1.0
# 154  0.173653  0.568807  0.273684    1.0  0.833333    0.341463        0.0
# 155  0.179641  0.422018  0.605263    1.0  0.866667    0.512195        0.0
# 156  0.101796  0.379205  0.331579    1.0  0.933333    0.487805        1.0
#
#      Weather_PS  Weather_S
# 0           0.0        1.0
# ...

# %%
minmax_scaled.describe()
# Out:
#             Ozone       solar        Wind       Month         Day  Tempreture  \
# count  157.000000  157.000000  157.000000  157.000000  157.000000  157.000000
# mean     0.228727    0.545464    0.433155    0.504777    0.497665    0.530371
# std      0.172347    0.266052    0.184484    0.358584    0.299147    0.229398
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.119760    0.366972    0.300000    0.250000    0.233333    0.390244
# 50%      0.179641    0.568807    0.421053    0.500000    0.500000    0.560976
# 75%      0.263473    0.758410    0.515789    0.750000    0.766667    0.682927
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#         Weather_C  Weather_PS   Weather_S
# count  157.000000  157.000000  157.000000
# mean     0.312102    0.299363    0.388535
# std      0.464834    0.459445    0.488977
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# ...

# %% [markdown]
# # auto EDA

# %%
# !pip install pandas_profiling==3.1.0
# !pip install -U ydata-profiling
# !pip install sweetviz

# %%
import pandas_profiling as pp
import sweetviz as sv

# %%
df =pd.read_csv('data_clean1.csv',index_col=[0])
df.head()
# Out:
#        Solar.R  Wind Month  Day  Year  Temp Weather
# Ozone
# 41.0     190.0   7.4     5    1  2010    67       S
# 36.0     118.0   8.0     5    2  2010    72       C
# 12.0     149.0  12.6     5    3  2010    74      PS
# 18.0     313.0  11.5     5    4  2010    62       S
# NaN        NaN  14.3     5    5  2010    56       S

# %%
EDA_report = pp.ProfileReport(df)

# %%
EDA_report
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.10.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-09-28 05:07:05.272976&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
